# %% [markdown]
# <a href="https://colab.research.google.com/github/ahneekgyun/CarCrash_Analytics/blob/main/weather_to_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Weather classification in image

# %% [markdown]
# 대회 링크
# https://dacon.io/competitions/official/236064/data

# %% [markdown]
# ## 가중치, csv저장 경로 설정

# %% [markdown]
# ####path, csv 저장 규칙
# 1. 공통된 부분은 이름을 같이 사용한다
# 2. 추론에 필요한 Hard_voting, Soft_voing 그리고 Frame의 갯수는 submit에만 필요함으로 뒤에 추가한다
# 2. EX) weather_resnet18_Del_Weight_Nt_NFC_NotFreeze_3frame_H
#
# ####각 항목별 설명
# resnet18, resnet 50, resnet101
# Del, NoDel -> 데이터 선별했음 Del, 데이터 선별 안함 NoDel
# Weight, Noweight -> 레이블 가중치 적용 비 적용
# Yt or Nt -> Yes_transform, No_transform
# FC or NFC -> FC레이어에 레이어 추가, NFC = FC레이어 그대로 사용
# Freeze or NotFreeze (레이어 동결 여부)
# Add (있으면 데이터 모델로 돌려 추가)
# 1frame, 3frame, 5frame
# H or S -> Hard_voing, Soft_voting

# %% [markdown]
# ### 실험 계획, 실행 현황

# %%
# 1차 실험
# 선별했음, 레이블가중치X, 전처리 X, 추가 FC레이어 X, 레이어 동결X , Hard voting

save_best_path_resnet18 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Nt_NFC_NotFreeze.pth'
save_submit_path_resnet18_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Nt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet18_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Nt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet18_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Nt_NFC_NotFreeze_5frame_H.csv'

save_best_path_resnet50 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Nt_NFC_NotFreeze.pth'
save_submit_path_resnet50_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Nt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet50_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Nt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet50_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Nt_NFC_NotFreeze_5frame_H.csv'

save_best_path_resnet101 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Nt_NFC_NotFreeze.pth'
save_submit_path_resnet101_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Nt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet101_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Nt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet101_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Nt_NFC_NotFreeze_5frame_H.csv'

# %%
#2차 실험
# 선별했음, 레이블가중치X, 전처리 1, 추가 FC레이어 X, 레이어 동결X , Hard voting


save_best_path_resnet18 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_NFC_NotFreeze.pth'
save_submit_path_resnet18_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet18_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet18_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_NFC_NotFreeze_5frame_H.csv'

save_best_path_resnet50 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_NFC_NotFreeze.pth'
save_submit_path_resnet50_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet50_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet50_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_NFC_NotFreeze_5frame_H.csv'

save_best_path_resnet101 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_NFC_NotFreeze.pth'
save_submit_path_resnet101_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_NFC_NotFreeze_1frame_H.csv'
save_submit_path_resnet101_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_NFC_NotFreeze_3frame_H.csv'
save_submit_path_resnet101_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_NFC_NotFreeze_5frame_H.csv'

# %%
# 3차 실험
# 선별했음, 레이블가중치X, 전처리 1, 추가 FC레이어 O, 레이어 동결X , Hard voting


save_best_path_resnet18 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_FC_NotFreeze.pth'
save_submit_path_resnet18_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_FC_NotFreeze_1frame_H.csv'
save_submit_path_resnet18_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_FC_NotFreeze_3frame_H.csv'
save_submit_path_resnet18_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet18_Del_NoWeight_Yt_FC_NotFreeze_5frame_H.csv'

save_best_path_resnet50 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_FC_NotFreeze.pth'
save_submit_path_resnet50_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_FC_NotFreeze_1frame_H.csv'
save_submit_path_resnet50_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_FC_NotFreeze_3frame_H.csv'
save_submit_path_resnet50_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet50_Del_NoWeight_Yt_FC_NotFreeze_5frame_H.csv'

save_best_path_resnet101 = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_FC_NotFreeze.pth'
save_submit_path_resnet101_1f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_FC_NotFreeze_1frame_H.csv'
save_submit_path_resnet101_3f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_FC_NotFreeze_3frame_H.csv'
save_submit_path_resnet101_5f = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/weather_resnet101_Del_NoWeight_Yt_FC_NotFreeze_5frame_H.csv'

# %%
# 4차 실험
# 선별했음, 레이블가중치X, 전처리 2, 추가 FC레이어 O, 레이어 동결X , Hard voting

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_NoWeight_Yt2_FC_NotFreeze'

# voting (H or S)
voting = 'H'

# ResNet18 경로
save_best_path_resnet18 = f"{base_path}/weather_resnet18_{option}.pth"
save_submit_path_resnet18_1f = f"{base_path}/weather_resnet18_{option}_1frame_{voting}.csv"
save_submit_path_resnet18_3f = f"{base_path}/weather_resnet18_{option}_3frame_{voting}.csv"
save_submit_path_resnet18_5f = f"{base_path}/weather_resnet18_{option}_5frame_{voting}.csv"

# ResNet50 경로
save_best_path_resnet50 = f"{base_path}/weather_resnet50_{option}.pth"
save_submit_path_resnet50_1f = f"{base_path}/weather_resnet50_{option}_1frame_{voting}.csv"
save_submit_path_resnet50_3f = f"{base_path}/weather_resnet50_{option}_3frame_{voting}.csv"
save_submit_path_resnet50_5f = f"{base_path}/weather_resnet50_{option}_5frame_{voting}.csv"

# ResNet101 경로
save_best_path_resnet101 = f"{base_path}/weather_resnet101_{option}.pth"
save_submit_path_resnet101_1f = f"{base_path}/weather_resnet101_{option}_1frame_{voting}.csv"
save_submit_path_resnet101_3f = f"{base_path}/weather_resnet101_{option}_3frame_{voting}.csv"
save_submit_path_resnet101_5f = f"{base_path}/weather_resnet101_{option}_5frame_{voting}.csv"

# %%
# 5차 실험
# 선별했음, 레이블가중치 O, 전처리 1, 추가 FC레이어 O, 레이어 동결X , Hard voting

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt_FC_NotFreeze'

# voting (H or S)
voting = 'H'

# ResNet18 경로
save_best_path_resnet18 = f"{base_path}/weather_resnet18_{option}.pth"
save_submit_path_resnet18_1f = f"{base_path}/weather_resnet18_{option}_1frame_{voting}.csv"
save_submit_path_resnet18_3f = f"{base_path}/weather_resnet18_{option}_3frame_{voting}.csv"
save_submit_path_resnet18_5f = f"{base_path}/weather_resnet18_{option}_5frame_{voting}.csv"

# ResNet50 경로
save_best_path_resnet50 = f"{base_path}/weather_resnet50_{option}.pth"
save_submit_path_resnet50_1f = f"{base_path}/weather_resnet50_{option}_1frame_{voting}.csv"
save_submit_path_resnet50_3f = f"{base_path}/weather_resnet50_{option}_3frame_{voting}.csv"
save_submit_path_resnet50_5f = f"{base_path}/weather_resnet50_{option}_5frame_{voting}.csv"

# ResNet101 경로
save_best_path_resnet101 = f"{base_path}/weather_resnet101_{option}.pth"
save_submit_path_resnet101_1f = f"{base_path}/weather_resnet101_{option}_1frame_{voting}.csv"
save_submit_path_resnet101_3f = f"{base_path}/weather_resnet101_{option}_3frame_{voting}.csv"
save_submit_path_resnet101_5f = f"{base_path}/weather_resnet101_{option}_5frame_{voting}.csv"

# %%
# 6차 실험
# 선별했음, 레이블가중치 O, 전처리 3, 추가 FC레이어 X, 레이어 동결X , Hard voting

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt3_NFC_NotFreeze'

# voting (H or S)
voting = 'H'

# ResNet18 경로
save_best_path_resnet18 = f"{base_path}/weather_resnet18_{option}.pth"
save_submit_path_resnet18_1f = f"{base_path}/weather_resnet18_{option}_1frame_{voting}.csv"
save_submit_path_resnet18_3f = f"{base_path}/weather_resnet18_{option}_3frame_{voting}.csv"
save_submit_path_resnet18_5f = f"{base_path}/weather_resnet18_{option}_5frame_{voting}.csv"

# ResNet50 경로
save_best_path_resnet50 = f"{base_path}/weather_resnet50_{option}.pth"
save_submit_path_resnet50_1f = f"{base_path}/weather_resnet50_{option}_1frame_{voting}.csv"
save_submit_path_resnet50_3f = f"{base_path}/weather_resnet50_{option}_3frame_{voting}.csv"
save_submit_path_resnet50_5f = f"{base_path}/weather_resnet50_{option}_5frame_{voting}.csv"

# ResNet101 경로
save_best_path_resnet101 = f"{base_path}/weather_resnet101_{option}.pth"
save_submit_path_resnet101_1f = f"{base_path}/weather_resnet101_{option}_1frame_{voting}.csv"
save_submit_path_resnet101_3f = f"{base_path}/weather_resnet101_{option}_3frame_{voting}.csv"
save_submit_path_resnet101_5f = f"{base_path}/weather_resnet101_{option}_5frame_{voting}.csv"

# %%
# 7차 실험
# 선별했음, 레이블가중치 O, 전처리 4, 추가 FC레이어 X, 레이어 동결X , Hard voting

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt4_NFC_NotFreeze'

# voting (H or S)
voting = 'H'

# ResNet18 경로
save_best_path_resnet18 = f"{base_path}/weather_resnet18_{option}.pth"
save_submit_path_resnet18_1f = f"{base_path}/weather_resnet18_{option}_1frame_{voting}.csv"
save_submit_path_resnet18_3f = f"{base_path}/weather_resnet18_{option}_3frame_{voting}.csv"
save_submit_path_resnet18_5f = f"{base_path}/weather_resnet18_{option}_5frame_{voting}.csv"

# ResNet50 경로
save_best_path_resnet50 = f"{base_path}/weather_resnet50_{option}.pth"
save_submit_path_resnet50_1f = f"{base_path}/weather_resnet50_{option}_1frame_{voting}.csv"
save_submit_path_resnet50_3f = f"{base_path}/weather_resnet50_{option}_3frame_{voting}.csv"
save_submit_path_resnet50_5f = f"{base_path}/weather_resnet50_{option}_5frame_{voting}.csv"

# ResNet101 경로
save_best_path_resnet101 = f"{base_path}/weather_resnet101_{option}.pth"
save_submit_path_resnet101_1f = f"{base_path}/weather_resnet101_{option}_1frame_{voting}.csv"
save_submit_path_resnet101_3f = f"{base_path}/weather_resnet101_{option}_3frame_{voting}.csv"
save_submit_path_resnet101_5f = f"{base_path}/weather_resnet101_{option}_5frame_{voting}.csv"

# %%
# 8차 실험
# 선별했음, 레이블가중치 O, 전처리 3, 추가 FC레이어 X, 레이어 동결X , Hard voting 데이터추가

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt3_NFC_NotFreeze_Add'

# voting (H or S)
voting = 'H'

# ResNet18 경로
save_best_path_resnet18 = f"{base_path}/weather_resnet18_{option}.pth"
save_submit_path_resnet18_1f = f"{base_path}/weather_resnet18_{option}_1frame_{voting}.csv"
save_submit_path_resnet18_3f = f"{base_path}/weather_resnet18_{option}_3frame_{voting}.csv"
save_submit_path_resnet18_5f = f"{base_path}/weather_resnet18_{option}_5frame_{voting}.csv"

# ResNet50 경로
save_best_path_resnet50 = f"{base_path}/weather_resnet50_{option}.pth"
save_submit_path_resnet50_1f = f"{base_path}/weather_resnet50_{option}_1frame_{voting}.csv"
save_submit_path_resnet50_3f = f"{base_path}/weather_resnet50_{option}_3frame_{voting}.csv"
save_submit_path_resnet50_5f = f"{base_path}/weather_resnet50_{option}_5frame_{voting}.csv"

# ResNet101 경로
save_best_path_resnet101 = f"{base_path}/weather_resnet101_{option}.pth"
save_submit_path_resnet101_1f = f"{base_path}/weather_resnet101_{option}_1frame_{voting}.csv"
save_submit_path_resnet101_3f = f"{base_path}/weather_resnet101_{option}_3frame_{voting}.csv"
save_submit_path_resnet101_5f = f"{base_path}/weather_resnet101_{option}_5frame_{voting}.csv"

# %%
# 9차 실험
# 선별했음, 레이블가중치 O, 전처리 4, 추가 FC레이어 X, 레이어 동결X , Hard voting, 데이터추가

# 모델 이름 변수
model1 = 'swin_base'
model2 = 'effifcientV2_m'
model3 = 'convnext_base'

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt3_NFC_NotFreeze_Add'

# 전처리옵션 4번 적용했지만 실수로 수정못함. 파일이름보고 착각하지말기

# voting (H or S)
voting = 'H'

# swin_base 경로
save_best_path_model1 = f"{base_path}/weather_{model1}_{option}.pth"
save_submit_path_model1_1f = f"{base_path}/weather_{model1}_{option}_1frame_{voting}.csv"
save_submit_path_model1_3f = f"{base_path}/weather_{model1}_{option}_3frame_{voting}.csv"
save_submit_path_model1_5f = f"{base_path}/weather_{model1}_{option}_5frame_{voting}.csv"

# effifcientV2_m 경로
save_best_path_model2 = f"{base_path}/weather_{model2}_{option}.pth"
save_submit_path_model2_1f = f"{base_path}/weather_{model2}_{option}_1frame_{voting}.csv"
save_submit_path_model2_3f = f"{base_path}/weather_{model2}_{option}_3frame_{voting}.csv"
save_submit_path_model2_5f = f"{base_path}/weather_{model2}_{option}_5frame_{voting}.csv"

# convnext_base 경로
save_best_path_model3 = f"{base_path}/weather_{model3}_{option}.pth"
save_submit_path_model3_1f = f"{base_path}/weather_{model3}_{option}_1frame_{voting}.csv"
save_submit_path_model3_3f = f"{base_path}/weather_{model3}_{option}_3frame_{voting}.csv"
save_submit_path_model3_5f = f"{base_path}/weather_{model3}_{option}_5frame_{voting}.csv"

# %%
# 10차 실험
# 선별했음, 레이블가중치 O, 전처리 3, 추가 FC레이어 X, 레이어 동결X , Hard voting, 데이터추가

# 모델 이름 변수
model1 = 'swin_base'
model2 = 'efficientnetv2_rw_m '
model3 = 'convnext_large'

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_NoWeight_Yt4_NFC_NotFreeze_Add'


# voting (H or S)
voting = 'H'

# swin_base 경로
save_best_path_model1 = f"{base_path}/weather_{model1}_{option}.pth"
save_submit_path_model1_1f = f"{base_path}/weather_{model1}_{option}_1frame_{voting}.csv"
save_submit_path_model1_3f = f"{base_path}/weather_{model1}_{option}_3frame_{voting}.csv"
save_submit_path_model1_5f = f"{base_path}/weather_{model1}_{option}_5frame_{voting}.csv"

# efficientnetv2_rw_m 경로
save_best_path_model2 = f"{base_path}/weather_{model2}_{option}.pth"
save_submit_path_model2_1f = f"{base_path}/weather_{model2}_{option}_1frame_{voting}.csv"
save_submit_path_model2_3f = f"{base_path}/weather_{model2}_{option}_3frame_{voting}.csv"
save_submit_path_model2_5f = f"{base_path}/weather_{model2}_{option}_5frame_{voting}.csv"

# convnext_large 경로
save_best_path_model3 = f"{base_path}/weather_{model3}_{option}.pth"
save_submit_path_model3_1f = f"{base_path}/weather_{model3}_{option}_1frame_{voting}.csv"
save_submit_path_model3_3f = f"{base_path}/weather_{model3}_{option}_3frame_{voting}.csv"
save_submit_path_model3_5f = f"{base_path}/weather_{model3}_{option}_5frame_{voting}.csv"

# %%
# 11차 실험
# 선별했음, 레이블가중치 O, 전처리 4, 추가 FC레이어 X, 레이어 동결X , Hard voting

# 모델 이름 변수
model1 = 'swin_base'
model2 = 'efficientnetv2_rw_m'
model3 = 'convnext_large'

# 공통 경로 및 옵션
base_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint'
option = 'Del_Weight_Yt4_NFC_NotFreeze'


# voting (H or S)
voting = 'H'

# swin_base 경로
save_best_path_model1 = f"{base_path}/weather_{model1}_{option}.pth"
save_submit_path_model1_1f = f"{base_path}/weather_{model1}_{option}_1frame_{voting}.csv"
save_submit_path_model1_3f = f"{base_path}/weather_{model1}_{option}_3frame_{voting}.csv"

# efficientnetv2_rw_m 경로
save_best_path_model2 = f"{base_path}/weather_{model2}_{option}.pth"
save_submit_path_model2_1f = f"{base_path}/weather_{model2}_{option}_1frame_{voting}.csv"
save_submit_path_model2_3f = f"{base_path}/weather_{model2}_{option}_3frame_{voting}.csv"

# convnext_large 경로
save_best_path_model3 = f"{base_path}/weather_{model3}_{option}.pth"
save_submit_path_model3_1f = f"{base_path}/weather_{model3}_{option}_1frame_{voting}.csv"
save_submit_path_model3_3f = f"{base_path}/weather_{model3}_{option}_3frame_{voting}.csv"

# %% [markdown]
# ## 패키지 로딩

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import random
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plat
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import timm

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import torchvision.models as models

from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

import warnings
warnings.filterwarnings(action='ignore')

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ## CFG - Configuration

# %%
CFG = {
    'VIDEO_LENGTH':50, # 10프레임 * 5초
    'IMG_SIZE':224,
    'EPOCHS':50,
    'LEARNING_RATE':1e-5,
    'BATCH_SIZE':32,
    'SEED':1204
}

# %% [markdown]
# ## 모델 설정

# %%
# FC레이어를 수정하지 않는 경우

# 1차 실험
# 2차 실험
# 6차 실험
# 7차 실험
'''
# resnet 18
model18 = models.resnet18(pretrained=True)
model18.fc = nn.Linear(512, 3)

# resnet 50
model50 = models.resnet50(pretrained=True)
model50.fc = nn.Linear(2048, 3)

# resnet 101
model101 = models.resnet101(pretrained=True)
model101.fc = nn.Linear(2048, 3)
'''
# Out:
# '\n# resnet 18\nmodel18 = models.resnet18(pretrained=True)\nmodel18.fc = nn.Linear(512, 3)\n\n# resnet 50\nmodel50 = models.resnet50(pretrained=True)\nmodel50.fc = nn.Linear(2048, 3)\n\n# resnet 101\nmodel101 = models.resnet101(pretrained=True)\nmodel101.fc = nn.Linear(2048, 3)\n'

# %%
# FC레이어를 수정하는 경우

# 3차 실험
# 4차 실험
# 5차 실험

'''
# resnet 18
model18 = models.resnet18(pretrained=True)
model18.fc = nn.Sequential(
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 3)
        )

# resnet 50
model50 = models.resnet50(pretrained=True)
model50.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 3)
        )

# resnet 101
model101 = models.resnet101(pretrained=True)
model101.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 3)
        )
'''
# Out:
# '\n# resnet 18\nmodel18 = models.resnet18(pretrained=True)\nmodel18.fc = nn.Sequential(\n            nn.Linear(512, 128),\n            nn.ReLU(),\n            nn.Dropout(0.5),\n            nn.Linear(128, 3)\n        )\n\n# resnet 50\nmodel50 = models.resnet50(pretrained=True)\nmodel50.fc = nn.Sequential(\n            nn.Linear(2048, 512),\n            nn.ReLU(),\n            nn.Dropout(0.5),\n            nn.Linear(512, 3)\n        )\n\n# resnet 101\nmodel101 = models.resnet101(pretrained=True)\nmodel101.fc = nn.Sequential(\n            nn.Linear(2048, 512),\n            nn.ReLU(),\n            nn.Dropout(0.5),\n            nn.Linear(512, 3)\n        )\n'

# %%
# 9차실험
'''
# Swin Transformer Base model
from timm.models.layers import SelectAdaptivePool2d
from timm.models.layers import ClassifierHead

model_1 = timm.create_model('swin_base_patch4_window7_224', pretrained=True, img_size=224)

# 새로운 head 정의
model_1.head = ClassifierHead(
    model_1.num_features,  # 모델의 출력 특징 맵 크기
    3,  # 원하는 출력 클래스 수
    pool_type= 'avg',  # 풀링 타입 설정
    drop_rate=0.0,  # 드롭아웃 비율 설정
    input_fmt=model_1.output_fmt  # 출력 형식 설정
)

# EfficientNetV2 Medium model
model_2 = timm.create_model('tf_efficientnetv2_m', pretrained=True)
model_2.classifier = nn.Sequential(
    nn.BatchNorm1d(model_2.num_features),
    nn.Linear(model_2.num_features, 512, bias=False),
    nn.ReLU(),
    nn.BatchNorm1d(512),
    nn.Dropout(0.4),
    nn.Linear(512, 3, bias=False)
)

# ConvNeXt Base model
model_3 = timm.create_model('convnext_base', pretrained=True)
model_3.head = nn.Sequential(
    SelectAdaptivePool2d(pool_type='avg', flatten=nn.Identity()),
    nn.LayerNorm([1024], eps=1e-06, elementwise_affine=True),
    nn.Flatten(start_dim=1, end_dim=-1),
    nn.Identity(),
    nn.Dropout(p=0.0, inplace=False),
    nn.Linear(1024, 3, bias=True)  # out_features를 3으로 설정
)
'''
# Out:
# "\n# Swin Transformer Base model\nfrom timm.models.layers import SelectAdaptivePool2d\nfrom timm.models.layers import ClassifierHead\n\nmodel_1 = timm.create_model('swin_base_patch4_window7_224', pretrained=True, img_size=224)\n\n# 새로운 head 정의\nmodel_1.head = ClassifierHead(\n    model_1.num_features,  # 모델의 출력 특징 맵 크기\n    3,  # 원하는 출력 클래스 수\n    pool_type= 'avg',  # 풀링 타입 설정\n    drop_rate=0.0,  # 드롭아웃 비율 설정\n    input_fmt=model_1.output_fmt  # 출력 형식 설정\n)\n\n# EfficientNetV2 Medium model\nmodel_2 = timm.create_model('tf_efficientnetv2_m', pretrained=True)\nmodel_2.classifier = nn.Sequential(\n    nn.BatchNorm1d(model_2.num_features),\n    nn.Linear(model_2.num_features, 512, bias=False),\n    nn.ReLU(),\n    nn.BatchNorm1d(512),\n    nn.Dropout(0.4),\n    nn.Linear(512, 3, bias=False)\n)\n\n# ConvNeXt Base model\nmodel_3 = timm.create_model('convnext_base', pretrained=True)\nmodel_3.head = nn.Sequential(\n    SelectAdaptivePool2d(pool_type='avg', flatten=nn.Identity()),\n    nn.La
# ...

# %%
# 10차실험

# Swin Transformer Base model
from timm.models.layers import SelectAdaptivePool2d
from timm.models.layers import ClassifierHead

# swin-base
model_1 = timm.create_model('swin_base_patch4_window7_224', pretrained=True, img_size=224)
model_1.head = ClassifierHead(
    model_1.num_features,  # 모델의 출력 특징 맵 크기
    3,  # 원하는 출력 클래스 수
    pool_type= 'avg',  # 풀링 타입 설정
    drop_rate=0.0,  # 드롭아웃 비율 설정
    input_fmt=model_1.output_fmt  # 출력 형식 설정
)

# efficientnetv2_rw_m  Medium model
model_2 = timm.create_model('efficientnetv2_rw_m', pretrained=True)
model_2.classifier = nn.Linear(2152, 3, bias=True)

# convnext_large model
model_3 = timm.create_model('convnext_large', pretrained=True)

model_3.head = nn.Sequential(
    SelectAdaptivePool2d(pool_type='avg', flatten=nn.Identity()),
    nn.LayerNorm([1536], eps=1e-06, elementwise_affine=True),
    nn.Flatten(start_dim=1, end_dim=-1),
    nn.Identity(),
    nn.Dropout(p=0.0, inplace=False),
    nn.Linear(1536, 3, bias=True)  # out_features를 3으로 설정
)

# %% [markdown]
# ## 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 파일압축해제

# %%
import zipfile

# 파일 경로, 압축 해제할 경로 입력(드라이브 밖에 폴더로 설정해야함)
zip_file_name = '/content/drive/MyDrive/my_data/CarCrash_image/train.zip'
extraction_dir = '/content/data'

# 이미지 데이터 압축해제
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

# 대회용 동영상폴더 open 압축해제
zip_file_path = '/content/drive/MyDrive/image classification/open.zip'
extract_to_path = '/content/data1'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

# %%
# 라벨0 데이터 ZIP 압축 해제 코드
# 파일 경로 입력(라벨 0에 대해 분류하고 추가)

'''
zip_file_name = '/content/drive/MyDrive/my_data/CarCrash_image/train_image0.zip'
extraction_dir = '/content/data1'

with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)
'''
# Out:
# "\nzip_file_name = '/content/drive/MyDrive/my_data/CarCrash_image/train_image0.zip'\nextraction_dir = '/content/data1'\n\nwith zipfile.ZipFile(zip_file_name, 'r') as zip_ref:\n    zip_ref.extractall(extraction_dir)\n"

# %% [markdown]
# ## 이미지 출력 확인

# %%
import cv2
import matplotlib.pyplot as plt

# 이미지 경로 설정
image_path = '/content/data/train/TRAIN_0000_frame_0001.jpg'

# 이미지 읽기
image = cv2.imread(image_path)

# 이미지가 제대로 읽혔는지 확인
if image is not None:
    # OpenCV는 BGR 포맷으로 이미지를 읽으므로, 이를 RGB로 변환
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 이미지 출력
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.show()
else:
    print(f"Failed to load image at {image_path}")

# 이미지 차원 확인
image_rgb.shape
# Out:
# (720, 1280, 3)

# %% [markdown]
# ## 데이터 선별

# %%
df = pd.read_csv('/content/drive/MyDrive/my_data/CarCrash_image/frame_metadata00.csv')
df['label'].value_counts()
# Out:
# label
# 1     15900
# 7     15850
# 3      3900
# 2      2550
# 9      1700
# 11     1650
# 8      1500
# 5      1400
# 4       650
# 12      300
# 10      200
# 6       150
# Name: count, dtype: int64

# %%
# CSV 파일 불러오기
df = pd.read_csv('/content/drive/MyDrive/my_data/CarCrash_image/frame_metadata00.csv')

# label 업데이트
df.loc[df['image_name'].str.contains('TRAIN_2236|TRAIN_2596'), 'label'] = 0
df.loc[df['image_name'].str.contains('TRAIN_0061|TRAIN_0107|TRAIN_0123|TRAIN_0294|TRAIN_0800|TRAIN_1280|TRAIN_1590|TRAIN_2302|TRAIN_2548'), 'label'] = 1
df.loc[df['image_name'].str.contains('TRAIN_0056|TRAIN_0129|TRAIN_0149|TRAIN_0242|TRAIN_0263|TRAIN_0728|TRAIN_0861|TRAIN_0889|TRAIN_0896|TRAIN_0920|TRAIN_1098|TRAIN_1169|TRAIN_1251|TRAIN_1605|TRAIN_1654|TRAIN_1656|TRAIN_1698|TRAIN_1795|TRAIN_1839|TRAIN_1955|TRAIN_2249|TRAIN_2388|TRAIN_2647'), 'label'] = 3
df.loc[df['image_name'].str.contains('TRAIN_0221|TRAIN_0856|TRAIN_1081|TRAIN_1263|TRAIN_1488|TRAIN_1492|TRAIN_1874|TRAIN_2166|TRAIN_2555|TRAIN_2595|TRAIN_2622'), 'label'] = 4
df.loc[df['image_name'].str.contains('TRAIN_0017|TRAIN_0225|TRAIN_0306|TRAIN_1193|TRAIN_1771|TRAIN_1848|TRAIN_2140|TRAIN_2298|TRAIN_2532|TRAIN_2570'), 'label'] = 5
df.loc[df['image_name'].str.contains('TRAIN_0809'), 'label'] = 6
df.loc[df['image_name'].str.contains('TRAIN_0020|TRAIN_0507|TRAIN_0617|TRAIN_1023|TRAIN_1420|TRAIN_1531|TRAIN_2033|TRAIN_2063'), 'label'] = 7
df.loc[df['image_name'].str.contains('TRAIN_0332|TRAIN_0674|TRAIN_0720|TRAIN_0917|TRAIN_1287|TRAIN_1699|TRAIN_1923|TRAIN_1949|TRAIN_2239|TRAIN_2491|TRAIN_2534|TRAIN_2615'), 'label'] = 9
df.loc[df['image_name'].str.contains('TRAIN_0877|TRAIN_1728|TRAIN_2328|TRAIN_2685'), 'label'] = 10
df.loc[df['image_name'].str.contains('TRAIN_0341|TRAIN_1041|TRAIN_1581|TRAIN_1727|TRAIN_2607'), 'label'] = 11
df.loc[df['image_name'].str.contains('TRAIN_2571'), 'label'] = 12

# 삭제할 image_name 리스트 정리
del_list = ['TRAIN_0048', 'TRAIN_0234', 'TRAIN_0238', 'TRAIN_0325', 'TRAIN_0528', 'TRAIN_0554', 'TRAIN_0668',
            'TRAIN_0705', 'TRAIN_0875', 'TRAIN_1082', 'TRAIN_1151', 'TRAIN_1337', 'TRAIN_1362', 'TRAIN_1506',
            'TRAIN_1674', 'TRAIN_1681', 'TRAIN_1753', 'TRAIN_1838', 'TRAIN_2191', 'TRAIN_2356', 'TRAIN_2360',
            'TRAIN_2428', 'TRAIN_2451', 'TRAIN_2486', 'TRAIN_2558', 'TRAIN_2658']

# image_name 목록에 있는 행 삭제
pattern = '|'.join(del_list)
df = df[~df['image_name'].str.contains(pattern)]
df = df[df['label'] != 0]
# 데이터프레임 크기 확인
print(df.shape)
# Out:
# (44400, 3)

# %%
# 경로 변경 함수 정의
def update_path(old_path):
    return old_path.replace('/content/drive/MyDrive/my_data/CarCrash_image/train00', '/content/data/train')

# image_path 열의 값 변경
df['image_path'] = df['image_path'].apply(update_path)
df.head(2)
# Out:
#                   image_name                                     image_path  \
# 0  TRAIN_0000_frame_0000.jpg  /content/data/train/TRAIN_0000_frame_0000.jpg
# 1  TRAIN_0000_frame_0001.jpg  /content/data/train/TRAIN_0000_frame_0001.jpg
#
#    label
# 0      7
# 1      7

# %%
# 특정 프레임임만 사용하도록 csv파일 수정
frames_list = ['frame_0000', 'frame_0025', 'frame_0049']
df = df[df['image_name'].apply(lambda x: any(x.endswith(frame + '.jpg') for frame in frames_list))]
df.shape
# Out:
# (2664, 3)

# %% [markdown]
# ### weather에 대한 라벨 변경

# %%
# normal
df.loc[df['label'].isin([1, 2, 7, 8]), 'label'] = 0

# snowy
df.loc[df['label'].isin([3, 4, 9, 10]), 'label'] = 1

# rainy
df.loc[df['label'].isin([5, 6, 11, 12]), 'label'] = 2

df['label'].value_counts()
# Out:
# label
# 0    1902
# 1     513
# 2     249
# Name: count, dtype: int64

# %% [markdown]
# ## 시드설정

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ## 데이터 train-val Split

# %%
train, val, _, _ = train_test_split(df, df['label'], test_size=0.25, random_state=CFG['SEED'])

# %% [markdown]
# ## 모델로 예측한 이미지를 학습데이터에 추가

# %%
'''
df_add = pd.read_csv('/content/drive/MyDrive/my_data/CarCrash_image/add_metadata00.csv')

train, val, _, _ = train_test_split(df, df['label'], test_size=0.25, random_state=CFG['SEED'])
print('기존 학습 데이터')
print(train['label'].value_counts())

# train에 추가 데이터 결합
train = pd.concat([train, df_add], ignore_index=True)
print('라벨0 추가 데이터')
print(train['label'].value_counts())
'''
# Out:
# "\ndf_add = pd.read_csv('/content/drive/MyDrive/my_data/CarCrash_image/add_metadata00.csv')\n\ntrain, val, _, _ = train_test_split(df, df['label'], test_size=0.25, random_state=CFG['SEED'])\nprint('기존 학습 데이터')\nprint(train['label'].value_counts())\n\n# train에 추가 데이터 결합\ntrain = pd.concat([train, df_add], ignore_index=True)\nprint('라벨0 추가 데이터')\nprint(train['label'].value_counts())\n"

# %% [markdown]
# ## 데이터셋구성

# %%
class CustomDataset(Dataset):
    def __init__(self, image_path_list, label_list,transform):
        self.image_path_list = image_path_list
        self.label_list = label_list
        self.transform = transform

    def __getitem__(self, index):
        img_path = self.image_path_list[index]
        image = self.get_image(img_path)
        if self.transform:
            image = self.transform(image)

        if self.label_list is not None:
            label = self.label_list[index]
            return image, label
        else:
            return image

    def __len__(self):
        return len(self.image_path_list)


    def get_image(self, path):
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # RGB로 변환
        return Image.fromarray(img)

# %% [markdown]
# ### 전처리 transform

# %% [markdown]
# 전처리 없는용 transforms

# %%
# 전처리 없는 경우

# 1차 실험
'''
train_dataset = CustomDataset(train['image_path'].values, train['label'].values, transform=transform_val)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True,pin_memory=True, num_workers=0)

val_dataset = CustomDataset(val['image_path'].values, val['label'].values, transform=transform_val)
val_loader = DataLoader(val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False,pin_memory=True, num_workers=0)
'''
# Out:
# "\ntrain_dataset = CustomDataset(train['image_path'].values, train['label'].values, transform=transform_val)\ntrain_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True,pin_memory=True, num_workers=0)\n\nval_dataset = CustomDataset(val['image_path'].values, val['label'].values, transform=transform_val)\nval_loader = DataLoader(val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False,pin_memory=True, num_workers=0)\n"

# %%
# 전처리 옵션 1

# 2차 실험
# 3차 실험
'''
transform_train = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.RandomHorizontalFlip(p=0.5),  # 랜덤으로 좌우 반전
    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변형
    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.RandomErasing() # 특정 부분 지우기
])

transform_val = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
'''
# Out:
# "\ntransform_train = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.RandomHorizontalFlip(p=0.5),  # 랜덤으로 좌우 반전\n    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전\n    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변형\n    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),\n    transforms.RandomErasing() # 특정 부분 지우기\n])\n\ntransform_val = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])\n])\n"

# %%
# 전처리 옵션 2

# 4차 실험
# 5차 실험
'''
transform_train = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.RandomHorizontalFlip(p=0.3), # 랜덤으로 좌우 반전
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전
    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.RandomErasing()
])

transform_val = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
'''
# Out:
# "\ntransform_train = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.RandomHorizontalFlip(p=0.3), # 랜덤으로 좌우 반전\n    transforms.RandomVerticalFlip(p=0.3),\n    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전\n    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),\n    transforms.RandomErasing()\n])\n\ntransform_val = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])\n])\n"

# %%
# 전처리 옵션 3
'''
# 6차시험
transform_train = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.RandomHorizontalFlip(p=0.5),  # 랜덤으로 좌우 반전
    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변형
    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_val = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
'''
# Out:
# "\n# 6차시험\ntransform_train = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.RandomHorizontalFlip(p=0.5),  # 랜덤으로 좌우 반전\n    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전\n    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변형\n    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])\n])\n\ntransform_val = transforms.Compose([\n    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),\n    transforms.ToTensor(),\n    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])\n])\n"

# %%
# 전처리 옵션 4

# 7차 실험

# 9차 실험

# 10차 11차 실험
transform_train = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.RandomHorizontalFlip(p=0.5),  # 랜덤으로 좌우 반전
    transforms.RandomRotation(degrees=25),  # 랜덤으로 회전
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변형
    transforms.RandomResizedCrop(CFG['IMG_SIZE'], scale=(0.7, 1.0)),  # 랜덤 크롭 및 리사이즈
    transforms.ToTensor(),
    transforms.RandomErasing(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

transform_val = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# .

# %% [markdown]
# 전처리 사용 transforms

# %%
# 전처리 사용하는 경우

train_dataset = CustomDataset(train['image_path'].values, train['label'].values, transform=transform_train)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=True,pin_memory=True, num_workers=0)

val_dataset = CustomDataset(val['image_path'].values, val['label'].values, transform=transform_val)
val_loader = DataLoader(val_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False,pin_memory=True, num_workers=0)

# %% [markdown]
# ## Train, Val, Test 설정

# %% [markdown]
# #### 가중치 설정

# %%
# 레이블 가중치 설정
# 기존 레이블은 약 1900, 500, 300의 비율로 존재

# 5차 실험
'''
class_counts = [1900, 500, 300]
class_weights = [1.0 / count for count in class_counts]
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
'''
# Out:
# '\nclass_counts = [1900, 500, 300]\nclass_weights = [1.0 / count for count in class_counts]\nclass_weights = torch.tensor(class_weights, dtype=torch.float).to(device)\n'

# %%
# 6차 실험
# 7차 실험
# 11차 실험

class_counts = [30000, 6000, 5000]
class_weights = [1.0 / count for count in class_counts]
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

# %%
# 9차실험
'''
class_counts = [1500, 500, 500]
class_weights = [1.0 / count for count in class_counts]
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
'''
# Out:
# '\nclass_counts = [1500, 500, 500]\nclass_weights = [1.0 / count for count in class_counts]\nclass_weights = torch.tensor(class_weights, dtype=torch.float).to(device)\n'

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.001):
        self.patience = patience
        self.delta = delta
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_score_min = np.Inf

    def __call__(self, val_score, model, model_path):
        score = val_score
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(score, model, model_path)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0
            self.save_checkpoint(score, model, model_path)

    def save_checkpoint(self, val_score, model, model_path):
        if val_score < self.val_score_min:
            print(f'Validation score decreased ({self.val_score_min:.6f} --> {val_score:.6f}).  Saving model ...')
            torch.save(model.state_dict(), model_path)
        self.val_score_min = val_score


def train(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)

    #가중치 X
    #criterion = nn.CrossEntropyLoss().to(device)

    #가중치 사용할 때
    criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)

    early_stop = EarlyStopping(patience=5, delta=0.001)
    best_val_score = 0
    best_model = None

    train_loss_epoch, valid_loss_epoch, valid_score_epoch = [], [], []
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for images, labels in tqdm(iter(train_loader)):
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            output = model(images)
            loss = criterion(output, labels)

            loss.backward()
            optimizer.step()

            train_loss.append(loss.item())

        _val_loss, _val_score = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val F1 : [{_val_score:.5f}]')

        train_loss_epoch.append(_train_loss)
        valid_loss_epoch.append(_val_loss)
        valid_score_epoch.append(_val_score)

        if scheduler is not None:
            scheduler.step(_val_score)

        early_stop(_val_score, model, save_best_path)

        if early_stop.early_stop:
            print("Early stopping")
            break

        if best_val_score < _val_score:
            best_val_score = _val_score
            best_model = model
            print('***** Best Model *****')
            torch.save(best_model.state_dict(), save_best_path)

    return best_model, train_loss_epoch, valid_loss_epoch, valid_score_epoch

def validation(model, criterion, val_loader, device):
    model.eval()
    val_loss = []
    preds, trues = [], []

    with torch.no_grad():
        for images, labels in tqdm(iter(val_loader)):
            images = images.to(device)
            labels = labels.to(device)

            logit = model(images)

            loss = criterion(logit, labels)

            val_loss.append(loss.item())

            preds += logit.argmax(1).detach().cpu().numpy().tolist()
            trues += labels.detach().cpu().numpy().tolist()

        _val_loss = np.mean(val_loss)

    _val_score = f1_score(trues, preds, average='macro')
    return _val_loss, _val_score


def inference(model, test_loader, device):
    model.to(device)
    model.eval()
    preds = []
    with torch.no_grad():
        for images in tqdm(iter(test_loader)):
            images = images.to(device)

            logit = model(images)

            preds += logit.argmax(1).detach().cpu().numpy().tolist()
    return preds

# soft voting을 위한 inference 코드
def inference_soft(model, test_loader, device):
    model.to(device)
    model.eval()
    preds = []
    with torch.no_grad():
        for images in tqdm(iter(test_loader)):
            images = images.to(device)

            logit = model(images)

    return logit

# %% [markdown]
# ## optimizer, scheduler, 모델학습

# %%
# model_1

# resnet 18
# 9차,10,11차 실험 swin_base

save_best_path = save_best_path_model1

optimizer = torch.optim.AdamW(params = model_1.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5,threshold_mode='abs',min_lr=1e-8, verbose=True)

infer_model_18, train_loss_epoch_, valid_loss_epoch_, valid_score_epoch_ = train(model_1, optimizer, train_loader, val_loader, scheduler, device)
# Out:
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [1], Train Loss : [0.96237] Val Loss : [0.70512] Val F1 : [0.65409]
# Validation score decreased (inf --> 0.654090).  Saving model ...
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [2], Train Loss : [0.58521] Val Loss : [0.37704] Val F1 : [0.79421]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [3], Train Loss : [0.36936] Val Loss : [0.30864] Val F1 : [0.81406]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [4], Train Loss : [0.32886] Val Loss : [0.26890] Val F1 : [0.81132]
# EarlyStopping counter: 1 out of 5
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [5], Train Loss : [0.26040] Val Loss : [0.25629] Val F1 : [0.83126]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [6], Train Loss : [0.23662] Val Loss : [0.26019] Val F1 : [0.85383]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# ...

# %%
# model_2

# resnet 50
# 9차 실험 effifcientV2_m
# 10,11차 실험 efficientnetv2_rw_m
save_best_path = save_best_path_model2

optimizer = torch.optim.AdamW(params = model_2.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5,threshold_mode='abs',min_lr=1e-8, verbose=True)

infer_model_50, train_loss_epoch_, valid_loss_epoch_, valid_score_epoch_ = train(model_2, optimizer, train_loader, val_loader, scheduler, device)
# Out:
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [1], Train Loss : [1.08290] Val Loss : [1.07551] Val F1 : [0.41913]
# Validation score decreased (inf --> 0.419128).  Saving model ...
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [2], Train Loss : [1.06486] Val Loss : [1.04782] Val F1 : [0.47283]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [3], Train Loss : [1.04217] Val Loss : [1.01756] Val F1 : [0.53427]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [4], Train Loss : [1.00092] Val Loss : [0.98056] Val F1 : [0.57555]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [5], Train Loss : [0.95616] Val Loss : [0.90874] Val F1 : [0.60890]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [6], Train Loss : [0.88413] Val Loss : [0.82977] Val F1 : [0.65820]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# ...

# %%
# model_3

# resnet 101
# 9차 실험 convnext_base
# 10,11차 실험 convnext-large
save_best_path = save_best_path_model3

optimizer = torch.optim.AdamW(params = model_3.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5,threshold_mode='abs',min_lr=1e-8, verbose=True)

infer_model_101, train_loss_epoch_, valid_loss_epoch_, valid_score_epoch_ = train(model_3, optimizer, train_loader, val_loader, scheduler, device)
# Out:
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [1], Train Loss : [0.94816] Val Loss : [0.71196] Val F1 : [0.64793]
# Validation score decreased (inf --> 0.647932).  Saving model ...
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [2], Train Loss : [0.57182] Val Loss : [0.46877] Val F1 : [0.74175]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [3], Train Loss : [0.40284] Val Loss : [0.39425] Val F1 : [0.82960]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [4], Train Loss : [0.30858] Val Loss : [0.30818] Val F1 : [0.81671]
# EarlyStopping counter: 1 out of 5
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [5], Train Loss : [0.24580] Val Loss : [0.34053] Val F1 : [0.86052]
# ***** Best Model *****
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# Epoch [6], Train Loss : [0.18944] Val Loss : [0.29830] Val F1 : [0.85679]
# EarlyStopping counter: 1 out of 5
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # 추론

# %% [markdown]
# ### 램던한 하나의 프레임으로 예측

# %%
transform_test = transforms.Compose([
    transforms.Resize((CFG['IMG_SIZE'], CFG['IMG_SIZE'])),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class Video_to_image_Dataset_1frame(Dataset):
    def __init__(self, video_path_list, transform=None, label_list=None):
        self.video_path_list = video_path_list
        self.label_list = label_list
        self.transform = transform

    def __getitem__(self, index):
        frame = self.get_random_frame(self.video_path_list[index])
        if self.transform:
            frame = self.transform(frame)

        if self.label_list is not None:
            label = self.label_list[index]
            return frame, label
        else:
            return frame

    def __len__(self):
        return len(self.video_path_list)

    def get_random_frame(self, path):
        cap = cv2.VideoCapture(path)
        frame_count = CFG['VIDEO_LENGTH']

        # 랜덤한 프레임 번호 선택
        random_frame = np.random.randint(0, frame_count)
        cap.set(cv2.CAP_PROP_POS_FRAMES, random_frame)

        ret, frame = cap.read()
        cap.release()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # RGB로 변환
        return Image.fromarray(frame)

# %%
# 데이터로더 구성

test = pd.read_csv('/content/data1/test.csv')
test['video_path'] = test['video_path'].str.replace('./test', '/content/data1/test')
test_dataset = Video_to_image_Dataset_1frame(test['video_path'].values,transform = transform_test)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)

# %%
# 경로 설정
save_submit_path = save_submit_path_model1_1f

preds = inference(infer_model_18, test_loader, device)
submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = preds
submit.to_csv(save_submit_path, index=False)
# Out:
#   0%|          | 0/1800 [00:00<?, ?it/s]

# %%
# 경로 설정
save_submit_path = save_submit_path_model2_1f

preds = inference(infer_model_50, test_loader, device)
submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = preds
submit.to_csv(save_submit_path, index=False)
# Out:
#   0%|          | 0/1800 [00:00<?, ?it/s]

# %%
# 경로 설정
save_submit_path = save_submit_path_model3_1f

preds = inference(infer_model_101, test_loader, device)
submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = preds
submit.to_csv(save_submit_path, index=False)
# Out:
#   0%|          | 0/1800 [00:00<?, ?it/s]

# %% [markdown]
# ## 3 frames Hard Voting + 5 frames

# %% [markdown]
# ### 0, 25, 49번째 프레임 선택해서 예측 + 12, 37번째

# %%
class Video_to_image_Dataset_3frame(Dataset):
    def __init__(self, video_path_list, transform=None, label_list=None, frame_number=None):
        self.video_path_list = video_path_list
        self.label_list = label_list
        self.transform = transform
        self.frame_number = frame_number

    def __getitem__(self, index):
        frame = self.get_frame(self.video_path_list[index], self.frame_number)
        if self.transform:
            frame = self.transform(frame)

        if self.label_list is not None:
            label = self.label_list[index]
            return frame, label
        else:
            return frame

    def __len__(self):
        return len(self.video_path_list)

    def get_frame(self, path, frame_number):
        cap = cv2.VideoCapture(path)
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

        ret, frame = cap.read()
        cap.release()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # RGB로 변환
        return Image.fromarray(frame)

# %%
# resnet 18

test = pd.read_csv('/content/data1/test.csv')

test['video_path'] = test['video_path'].str.replace('./test', '/content/data1/test')

# for 3 frames - Hard
test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=0)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds1 = inference(infer_model_18, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=24)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds2 = inference(infer_model_18, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=49)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds3 = inference(infer_model_18, test_loader, device)



# for 3 frames - Hard
df_preds1 = pd.DataFrame(preds1, columns=['label'])
df_preds2 = pd.DataFrame(preds2, columns=['label'])
df_preds3 = pd.DataFrame(preds3, columns=['label'])



# 라벨 분포 확인해보기
print('5개의 모델에 대한 Label 분포')
print(df_preds1['label'].value_counts())
print(df_preds2['label'].value_counts())
print(df_preds3['label'].value_counts())



############## for 3 frames #################
final_preds = []
for i in range(len(preds1)):
    vote = np.argmax(np.bincount([preds1[i], preds2[i], preds3[i]]))
    final_preds.append(vote)

# 저장 경로 설정
save_submit_path = save_submit_path_model1_3f

submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = final_preds
submit.to_csv(save_submit_path, index=False)
# Out:
# ...
#   0%|          | 0/1800 [00:00<?, ?it/s]
# 5개의 모델에 대한 Label 분포
# label
# 0    1458
# 1     226
# 2     116
# Name: count, dtype: int64
# label
# 0    1448
# 1     231
# 2     121
# Name: count, dtype: int64
# label
# 0    1427
# 1     250
# 2     123
# Name: count, dtype: int64

# %%
# resnet 50

test = pd.read_csv('/content/data1/test.csv')

test['video_path'] = test['video_path'].str.replace('./test', '/content/data1/test')

# for 3 frames
test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=0)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds1 = inference(infer_model_50, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=24)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds2 = inference(infer_model_50, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=49)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds3 = inference(infer_model_50, test_loader, device)


# for 3 frames
df_preds1 = pd.DataFrame(preds1, columns=['label'])
df_preds2 = pd.DataFrame(preds2, columns=['label'])
df_preds3 = pd.DataFrame(preds3, columns=['label'])



# 라벨 분포 확인해보기
print('5개의 모델에 대한 Label 분포')
print(df_preds1['label'].value_counts())
print(df_preds2['label'].value_counts())
print(df_preds3['label'].value_counts())


############## for 3 frames #################
final_preds = []
for i in range(len(preds1)):
    vote = np.argmax(np.bincount([preds1[i], preds2[i], preds3[i]]))
    final_preds.append(vote)

# 저장 경로 설정
save_submit_path = save_submit_path_model2_3f

submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = final_preds
submit.to_csv(save_submit_path, index=False)
# Out:
# ...
#   0%|          | 0/1800 [00:00<?, ?it/s]
# 5개의 모델에 대한 Label 분포
# label
# 0    1412
# 1     248
# 2     140
# Name: count, dtype: int64
# label
# 0    1412
# 1     238
# 2     150
# Name: count, dtype: int64
# label
# 0    1406
# 1     250
# 2     144
# Name: count, dtype: int64

# %%
# resnet 101

test = pd.read_csv('/content/data1/test.csv')

test['video_path'] = test['video_path'].str.replace('./test', '/content/data1/test')

# for 3 frames
test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=0)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds1 = inference(infer_model_101, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=24)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds2 = inference(infer_model_101, test_loader, device)

test_dataset = Video_to_image_Dataset_3frame(test['video_path'].values,transform = transform_test, frame_number=49)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle=False, num_workers=0)
preds3 = inference(infer_model_101, test_loader, device)

# for 3 frames
df_preds1 = pd.DataFrame(preds1, columns=['label'])
df_preds2 = pd.DataFrame(preds2, columns=['label'])
df_preds3 = pd.DataFrame(preds3, columns=['label'])


# 라벨 분포 확인해보기
print('5개의 모델에 대한 Label 분포')
print(df_preds1['label'].value_counts())
print(df_preds2['label'].value_counts())
print(df_preds3['label'].value_counts())


############## for 3 frames #################
final_preds = []
for i in range(len(preds1)):
    vote = np.argmax(np.bincount([preds1[i], preds2[i], preds3[i]]))
    final_preds.append(vote)

# 저장 경로 설정
save_submit_path = save_submit_path_model3_3f

submit = pd.read_csv('/content/data1/sample_submission.csv')
submit['label'] = final_preds
submit.to_csv(save_submit_path, index=False)
# Out:
# ...
#   0%|          | 0/1800 [00:00<?, ?it/s]
# 5개의 모델에 대한 Label 분포
# label
# 0    1504
# 1     191
# 2     105
# Name: count, dtype: int64
# label
# 0    1489
# 1     193
# 2     118
# Name: count, dtype: int64
# label
# 0    1483
# 1     192
# 2     125
# Name: count, dtype: int64

# %% [markdown]
# # 사용했던 코드 부록

# %% [markdown]
# 가중치를 불러오는 경우 사용

# %%
# # .pth 파일 경로
# model_path = '/content/drive/MyDrive/my_data/CarCrash_image/model_checkpoint/best_weather_model_0607_4.pth'

# # 가중치 불러오기
# model.load_state_dict(torch.load(model_path))

# %%
# model = models.resnet50(pretrained=True)
# model.fc = nn.Sequential(
#             nn.Linear(2048, 512),
#             nn.ReLU(),
#             nn.Dropout(0.5),
#             nn.Linear(512, 3)
#         )

# %%
# 마지막 분류레이어만 학습
# for name, param in model.named_parameters():
#     if "fc" in name:  # Unfreeze the final classification layer
#         param.requires_grad = True
#     else:
#         param.requires_grad = False
'''
optimizer = torch.optim.AdamW(params = model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2,threshold_mode='abs',min_lr=1e-8, verbose=True)

infer_model, train_loss_epoch_, valid_loss_epoch_, valid_score_epoch_ = train(model, optimizer, train_loader, val_loader, scheduler, device)
''';
